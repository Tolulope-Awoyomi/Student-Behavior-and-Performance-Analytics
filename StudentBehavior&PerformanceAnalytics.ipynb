# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Read dataset
df = pd.read_csv("/content/drive/MyDrive/Student_Behaviour.csv")

# %%
# See top 5 rows
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
# See the sahpe of the dataset
df.shape
# Out:
# (235, 19)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Certification Course                                      0
# Gender                                                    0
# Department                                                0
# Height(CM)                                                0
# Weight(KG)                                                0
# 10th Mark                                                 0
# 12th Mark                                                 0
# college mark                                              0
# hobbies                                                   0
# daily studing time                                        0
# prefer to study in                                        0
# salary expectation                                        0
# Do you like your degree?                                  0
# willingness to pursue a career based on their degree      0
# social medai & video                                      0
# Travelling Time                                           0
# ...

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check the null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    object
#  1   Gender                                                  235 non-null    object
#  2   Department                                              235 non-null    object
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
# Check for unique values
df.nunique()
# Out:
# Certification Course                                       2
# Gender                                                     2
# Department                                                 4
# Height(CM)                                                56
# Weight(KG)                                                52
# 10th Mark                                                 68
# 12th Mark                                                 67
# college mark                                              43
# hobbies                                                    4
# daily studing time                                         6
# prefer to study in                                         3
# salary expectation                                        34
# Do you like your degree?                                   2
# willingness to pursue a career based on their degree       5
# social medai & video                                       6
# ...

# %%
# Explore the data
print("Categories in 'Certification Course' variable:  ",end=" ")
print(df["Certification Course"].unique())

print("Categories in 'Gender' variable:  ",end=" ")
print(df["Gender"].unique())

print("Categories in 'Department' variable:  ",end=" ")
print(df["Department"].unique())

print("Categories in 'Height(CM)' variable:  ",end=" ")
print(df["Height(CM)"].unique())

print("Categories in 'Weight(KG)' variable:  ",end=" ")
print(df["Weight(KG)"].unique())

print("Categories in '10th Mark' variable:  ",end=" ")
print(df["10th Mark"].unique())

print("Categories in '12th Mark' variable:  ",end=" ")
print(df["12th Mark"].unique())

print("Categories in 'college mark' variable:  ",end=" ")
print(df["college mark"].unique())

print("Categories in 'hobbies' variable:  ",end=" ")
print(df["hobbies"].unique())

print("Categories in 'daily studing time' variable:  ",end=" ")
print(df["daily studing time"].unique())

print("Categories in 'prefer to study in' variable:  ",end=" ")
print(df["prefer to study in"].unique())

print("Categories in 'salary expectation' variable:  ",end=" ")
print(df["salary expectation"].unique())

print("Categories in 'Do you like your degree?' variable:  ",end=" ")
print(df["Do you like your degree?"].unique())

print("Categories in 'social media & video' variable:  ",end=" ")
print(df["social medai & video"].unique())

print("Categories in 'Financial Status' variable:  ",end=" ")
print(df["Financial Status"].unique())
# Out:
# Categories in 'Certification Course' variable:   ['No' 'Yes']
# Categories in 'Gender' variable:   ['Male' 'Female']
# Categories in 'Department' variable:   ['BCA' 'Commerce' 'B.com Accounting and Finance ' 'B.com ISM']
# Categories in 'Height(CM)' variable:   [100.   90.  159.  147.  170.  139.  165.  152.  190.  150.   99.  158.
#  160.  156.  153.  162.  109.  154.  142.  180.  167.  175.  151.  145.
#  163.  144.  155.  185.   98.  157.  146.  172.  106.  171.  177.  174.
#    4.5 178.  183.  181.  179.  187.  132.  169.  134.  120.  182.  148.
#  130.  140.  192.  173.  149.  168.  161.  164. ]
# Categories in 'Weight(KG)' variable:   [ 58.   40.   78.   20.   54.   33.   50.   43.   85.   84.   51.   64.
#   52.   83.   68.   60.   42.   90.   89.   73.   69.   39.   63.   55.
#   70.   48.   45.   72.   35.   95.   65.   80.   56.   53.   67.   47.
#   62.   61.   75.   93.   74.   91.   76.   49.   57.   86.   38.   68.9
#  106.   59.   92.   32. ]
# ...

# %%
# Define numerical and categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != "object"]
categorical_features = [feature for feature in df.columns if df[feature].dtype == "object"]

print("We have {} numerical features: {}".format(len(numeric_features),numeric_features))
print("We have {} categorical features: {}".format(len(categorical_features),categorical_features))
# Out:
# We have 6 numerical features: ['Height(CM)', 'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'salary expectation']
# We have 13 categorical features: ['Certification Course', 'Gender', 'Department', 'hobbies', 'daily studing time', 'prefer to study in', 'Do you like your degree?', 'willingness to pursue a career based on their degree  ', 'social medai & video', 'Travelling Time ', 'Stress Level ', 'Financial Status', 'part-time job']

# %% [markdown]
# EXPLORING DATA

# %%
# Create bar plots to visualize the distribution of 'Certification Course,' 'Gender,' and 'Department'
plt.figure(figsize=(15, 5))

plt.subplot(131)  # Certification Course
sns.countplot(x='Certification Course', data=df, palette='Set2')
plt.title('Certification Course Distribution', fontsize=16)
plt.xlabel('Certification Course', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)

plt.subplot(132)  # Gender
sns.countplot(x='Gender', data=df, palette='Set2')
plt.title('Gender Distribution', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Count', fontsize=14)

plt.subplot(133)  # Department
sns.countplot(x='Department', data=df, palette='Set2')
plt.title('Department Distribution', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)

plt.tight_layout()
plt.show()

# Create pie charts for 'Certification Course' and 'Gender'
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart for 'Certification Course'
certification_course_counts = df['Certification Course'].value_counts()
axes[0].pie(certification_course_counts, labels=certification_course_counts.index, autopct='%1.1f%%', shadow=True, colors=['#ff4d4d', '#ff8000'])
axes[0].set_title('Certification Course Distribution', fontsize=16)

# Pie chart for 'Gender'
gender_counts = df['Gender'].value_counts()
axes[1].pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', shadow=True, colors=['#ff4d4d', '#ff8000'])
axes[1].set_title('Gender Distribution', fontsize=16)

plt.show()

# %%
# Create a bar plot to visualize the distribution of hobbies
plt.figure(figsize=(10, 6))
sns.countplot(x='hobbies', data=df, palette='Set2')
plt.title('Distribution of Hobbies Among Students', fontsize=13)
plt.xlabel('Hobbies', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# Convert 'college mark' to a numeric format (e.g., remove '%' and convert to float)
df['College Mark Numeric'] = df['college mark'].str.rstrip('%').astype(float)

# Ensure 'hobbies' is a categorical variable
df['hobbies'] = df['hobbies'].astype('category')

# Create a box plot to examine the relationship between hobbies and academic performance (e.g., College Mark)
plt.figure(figsize=(10, 6))
sns.boxplot(x='hobbies', y='College Mark Numeric', data=df, palette='Set2')
plt.title('Academic Performance vs. Hobbies', fontsize=13)
plt.xlabel('Hobbies', fontsize=14)
plt.ylabel('College Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Create a bar plot to visualize the distribution of hobbies
plt.figure(figsize=(10, 6))
sns.countplot(x='hobbies', data=df, palette='Set2')
plt.title('Distribution of Hobbies Among Students', fontsize=13)
plt.xlabel('Hobbies', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# Create a box plot to examine the relationship between hobbies and academic performance (e.g., 10th Mark)
plt.figure(figsize=(10, 6))
sns.boxplot(x='hobbies', y='10th Mark', data=df, palette='Set2')
plt.title('Academic Performance vs. Hobbies', fontsize=13)
plt.xlabel('Hobbies', fontsize=14)
plt.ylabel('10th Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Create a bar plot to visualize the distribution of hobbies
plt.figure(figsize=(10, 6))
sns.countplot(x='hobbies', data=df, palette='Set2')
plt.title('Distribution of Hobbies Among Students', fontsize=13)
plt.xlabel('Hobbies', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# Create a box plot to examine the relationship between hobbies and academic performance (e.g., 10th Mark)
plt.figure(figsize=(10, 6))
sns.boxplot(x='hobbies', y='12th Mark', data=df, palette='Set2')
plt.title('Academic Performance vs. Hobbies', fontsize=13)
plt.xlabel('Hobbies', fontsize=14)
plt.ylabel('10th Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Create a contingency table for 'Gender' and 'Certification Course'
contingency_table = pd.crosstab(df['Gender'], df['Certification Course'])

# Perform the chi-square test of independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies table:")
print(expected)

# Create a heatmap to visualize the contingency table
plt.figure(figsize=(8, 6))
sns.heatmap(contingency_table, annot=True, fmt="d", cmap="YlGnBu")
plt.title("Contingency Table: Gender vs. Certification Course", fontsize=16)
plt.show()

# Create a heatmap to visualize the expected frequencies table
plt.figure(figsize=(8, 6))
sns.heatmap(expected, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title("Expected Frequencies Table", fontsize=16)
plt.show()
# Out:
# Chi-square statistic: 0.966120791460312
# P-value: 0.3256495515188808
# Degrees of freedom: 1
# Expected frequencies table:
# [[ 27.90212766  51.09787234]
#  [ 55.09787234 100.90212766]]

# %%
# Data Exploration
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', data=df, palette='Set2')
plt.title('Department Distribution', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# Convert 'college mark' to a numeric format (e.g., remove '%' and convert to float)
df['College Mark Numeric'] = df['college mark'].str.rstrip('%').astype(float)

# Ensure 'Department' is a categorical variable
df['Department'] = df['Department'].astype('category')

# Box plot to compare academic performance based on department
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='College Mark Numeric', data=df, palette='viridis')
plt.title('College Mark vs. Department', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('College Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Data Exploration
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', data=df, palette='Set2')
plt.title('Department Distribution', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# Box plot to compare academic performance based on department
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='10th Mark', data=df, palette='viridis')
plt.title('10th Mark vs. Department', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('10th Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Data Exploration
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', data=df, palette='Set2')
plt.title('Department Distribution', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# Box plot to compare academic performance based on department
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='10th Mark', data=df, palette='viridis')
plt.title('12th Mark vs. Department', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('10th Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Create a pair plot to visualize relationships between numeric attributes
numeric_attributes = ['Height(CM)', 'Weight(KG)', '10th Mark', '12th Mark', 'college mark']
sns.pairplot(df[numeric_attributes], height=2.5)
plt.suptitle('Pair Plot of Numeric Attributes', y=1.02, fontsize=16)
plt.show()

# Create a correlation matrix to quantify the relationships between numeric attributes
correlation_matrix = df[numeric_attributes].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix', fontsize=16)
plt.show()

# %%
# Calculate summary statistics for numerical columns
summary_stats = df[['Height(CM)', 'Weight(KG)', '10th Mark', '12th Mark', 'college mark']].describe()

# Print the summary statistics
print(summary_stats)
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000

# %%
import matplotlib.pyplot as plt

# Plot histograms for numerical columns
plt.figure(figsize=(12, 8))
numerical_columns = ['Height(CM)', 'Weight(KG)', '10th Mark', '12th Mark', 'college mark']

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(2, 3, i)
    plt.hist(df[col], bins=20, color='skyblue')
    plt.title(col, fontsize=14)
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Plot box plots for numerical columns
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[numerical_columns], palette='Set2')
plt.title('Box Plots of Numerical Columns', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('Value', fontsize=14)
plt.show()

# %%
# Create a countplot to compare hobbies based on department
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', hue='hobbies', data=df, palette='viridis')
plt.title('Hobbies vs. Department', fontsize=16)
plt.xlabel('Department', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.legend(title='Hobbies', title_fontsize=12, fontsize=12)
plt.show()

# %%
# Create a scatter plot to explore the relationship between 'Daily Study Time' and 'College Mark'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='daily studing time', y='college mark', data=df, palette='viridis')
plt.title('College Mark vs. Daily Study Time', fontsize=16)
plt.xlabel('Daily Study Time', fontsize=14)
plt.ylabel('College Mark', fontsize=14)
plt.show()

# %%
# Create a box plot to compare "College Mark" based on different levels of "Daily Study Time"
plt.figure(figsize=(10, 6))
sns.boxplot(x='daily studing time', y='college mark', data=df, palette='viridis')
plt.title('College Mark vs. Daily Study Time', fontsize=16)
plt.xlabel('Daily Study Time', fontsize=14)
plt.ylabel('College Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Check the data type of 'college mark' column
print(df['college mark'].dtype)

# If it's not already a string (str or object), convert it to a string
df['college mark'] = df['college mark'].astype(str)

# Now, you can use the .str accessor to remove the '%' and convert to float
df['College Mark Numeric'] = df['college mark'].str.rstrip('%').astype(float)

# Calculate the correlation
correlation = df['Daily Study Time Numeric'].corr(df['College Mark Numeric'])
print("Correlation between Daily Study Time and College Mark:", correlation)

# Create a correlation matrix for selected columns
correlation_matrix = df[['Daily Study Time Numeric', 'College Mark Numeric']].corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation between Daily Study Time and College Mark', fontsize=16)
plt.show()
# Out:
# object
# Correlation between Daily Study Time and College Mark: -0.054261745994528134

# %%
# Convert 'college mark' to a numeric format (e.g., remove '%' and convert to float)
df['College Mark Numeric'] = df['college mark'].str.rstrip('%').astype(float)

# Ensure 'Prefer to Study In' is a categorical variable
df['Prefer to Study In'] = df['prefer to study in'].astype('category')

# Create box plots to compare "College Mark" and "Daily Study Time" based on "Prefer to Study In"
plt.figure(figsize=(12, 6))
sns.boxplot(x='Prefer to Study In', y='College Mark Numeric', data=df, palette='viridis')
plt.title('College Mark vs. Prefer to Study In', fontsize=16)
plt.xlabel('Prefer to Study In', fontsize=14)
plt.ylabel('College Mark', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.show()

# %%
# Create a pair plot to visualize relationships between selected columns
sns.pairplot(df[['College Mark Numeric', 'Daily Study Time Numeric', 'prefer to study in']], hue='prefer to study in', palette='viridis', height=3)
plt.suptitle('Pair Plot of College Mark, Daily Study Time, and Prefer to Study In', y=1.02, fontsize=16)
plt.show()
